# %%
import pandas as pd
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
import pywt

# %%
data = pd.read_hdf('putEMG/Data-HDF5/emg_gestures-05-repeats_short-2018-04-23-08-35-24-986.hdf5')

# %%
data.date_time.tail()
# Out:
# 271.028334   2018-04-23 08:35:24.986
# 271.028529   2018-04-23 08:35:24.986
# 271.028724   2018-04-23 08:35:24.986
# 271.028919   2018-04-23 08:35:24.986
# 271.029114   2018-04-23 08:35:24.986
# Name: date_time, dtype: datetime64[ns]

# %%
x = data.EMG_7
f, t, Zxx = signal.stft(x, nperseg=100)
amp = 2 * np.sqrt(2)
plt.pcolormesh(t, f, np.abs(Zxx), vmin=0, vmax=amp, shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
x = data.EMG_15
cA, cD = pywt.dwt(x, 'db2')
y = pywt.wavedec(x, 'db2', mode='symmetric', level=None, axis=-1)
len(y)
# Out:
# 19

# %%
plt.plot(y[18])
plt.xlim([0, 40000])
plt.ylim([-20,20])
plt.title("D1")
plt.show()

# %%
plt.plot(y[17])
plt.xlim([0, 40000])
plt.ylim([-50,50])

plt.title("D2")
plt.show()

# %%
plt.plot(y[16])
plt.xlim([0, 40000])
plt.title("D3")

plt.show()

# %%
plt.plot(y[15])
plt.xlim([0, 40000])
plt.title("D4")

plt.show()

# %%
plt.plot(y[14])
plt.xlim([0, 40000])
plt.title("D5")


plt.show()

# %%
plt.plot(y[13])
plt.xlim([0, 20000])
plt.title("D6")

plt.show()

# %%
plt.plot(y[12])
plt.xlim([0, 11000])
plt.title("D7")

plt.show()

# %%
plt.plot(y[11])
plt.xlim([0, 6000])
plt.title("D8")

plt.show()

# %%
plt.plot(y[10])
# plt.xlim([0, 100000])
plt.title("D9")

plt.show()

# %%
plt.plot(y[9])
# plt.xlim([0, 100000])
plt.title("D10")

plt.show()

# %%
plt.plot(y[8])
# plt.xlim([0, 100000])
plt.show()

# %%
plt.plot(y[7])
# plt.xlim([0, 100000])
plt.show()

# %%
plt.plot(y[6])
# plt.xlim([0, 100000])
plt.show()

# %%
plt.plot(y[5])
# plt.xlim([0, 100000])
plt.show()

# %%
plt.plot(y[4])
# plt.xlim([0, 100000])
plt.show()

# %%
plt.plot(y[3])
# plt.xlim([0, 100000])
plt.show()

# %%
plt.plot(y[2])
# plt.xlim([0, 100000])
plt.show()

# %%
plt.plot(y[1])
# plt.xlim([0, 100000])
plt.show()

# %%
plt.plot(y[0])
# plt.xlim([0, 100000])
plt.show()
